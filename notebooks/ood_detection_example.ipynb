# %% [markdown]
# # Out-of-Distribution Detection Example
#
# This notebook demonstrates how to use the OOD detection methods implemented in this project.
#
# ## Overview
#
# Out-of-Distribution (OOD) detection is crucial for robust AI systems. This example shows:
# - Loading and preprocessing data
# - Training different OOD detection methods
# - Evaluating performance
# - Visualizing results
#
# ## Disclaimer
#
# This is for educational purposes only. OOD detection methods may be unstable and should not be used for regulated decisions without human review.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Import our OOD detection modules
import sys
import os
sys.path.append(os.path.join(os.path.dirname(__file__), "..", "src"))

from ood_detection.data import load_iris_dataset, preprocess_data
from ood_detection.methods import MahalanobisOODDetector, EnergyOODDetector
from ood_detection.eval import evaluate_ood_detection
from ood_detection.viz import plot_ood_scores, plot_roc_curve, plot_method_comparison
from ood_detection.utils import set_seed

# Set random seed for reproducibility
set_seed(42)

print("🔍 Out-of-Distribution Detection Example")
print("=" * 50)
